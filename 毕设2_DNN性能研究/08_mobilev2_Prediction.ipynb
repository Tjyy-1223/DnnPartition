# %%
import torch
import function
import a5_MobileNet

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
x = torch.rand(size=(256,3,224,224))
x = x.to(device)
print(f"x device : {x.device}")

mobileNet = a5_MobileNet.mobilenet_v2()
mobileNet = mobileNet.to(device)
# Out:
# x device : cuda:0

# %%
print(len(mobileNet))
# Out:
# 23

# %%
temp_x = x
with torch.no_grad():
    temp_x = function.show_features(mobileNet,temp_x)
# Out:
# ------------------------------------------------------------------
# 1-ConvNormActivation(
#   (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU6(inplace=True)
# )
# computation time: 0.685 s
# output shape: torch.Size([256, 32, 112, 112])	 transport_num:102760448    transport_size:411.042MB
# 0.weight  :  parameters size torch.Size([32, 3, 3, 3]) 	 parameters number 864
# 1.weight  :  parameters size torch.Size([32]) 	 parameters number 32
# 1.bias  :  parameters size torch.Size([32]) 	 parameters number 32
# ------------------------------------------------------------------
# 2-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 16, 112, 112])	 transport_num:51380224    transport_size:205.521MB
# conv.0.0.weight  :  parameters size torch.Size([32, 1, 3, 3]) 	 parameters number 288
# conv.0.1.weight  :  parameters size torch.Size([32]) 	 parameters number 32
# conv.0.1.bias  :  parameters size torch.Size([32]) 	 parameters number 32
# conv.1.weight  :  parameters size torch.Size([16, 32, 1, 1]) 	 parameters number 512
# conv.2.weight  :  parameters size torch.Size([16]) 	 parameters number 16
# conv.2.bias  :  parameters size torch.Size([16]) 	 parameters number 16
# ------------------------------------------------------------------
# 3-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.013 s
# output shape: torch.Size([256, 24, 56, 56])	 transport_num:19267584    transport_size:77.070MB
# conv.0.0.weight  :  parameters size torch.Size([96, 16, 1, 1]) 	 parameters number 1536
# conv.0.1.weight  :  parameters size torch.Size([96]) 	 parameters number 96
# conv.0.1.bias  :  parameters size torch.Size([96]) 	 parameters number 96
# conv.1.0.weight  :  parameters size torch.Size([96, 1, 3, 3]) 	 parameters number 864
# conv.1.1.weight  :  parameters size torch.Size([96]) 	 parameters number 96
# conv.1.1.bias  :  parameters size torch.Size([96]) 	 parameters number 96
# conv.2.weight  :  parameters size torch.Size([24, 96, 1, 1]) 	 parameters number 2304
# conv.3.weight  :  parameters size torch.Size([24]) 	 parameters number 24
# conv.3.bias  :  parameters size torch.Size([24]) 	 parameters number 24
# ------------------------------------------------------------------
# 4-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#       (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.0 s
# output shape: torch.Size([256, 24, 56, 56])	 transport_num:19267584    transport_size:77.070MB
# conv.0.0.weight  :  parameters size torch.Size([144, 24, 1, 1]) 	 parameters number 3456
# conv.0.1.weight  :  parameters size torch.Size([144]) 	 parameters number 144
# conv.0.1.bias  :  parameters size torch.Size([144]) 	 parameters number 144
# conv.1.0.weight  :  parameters size torch.Size([144, 1, 3, 3]) 	 parameters number 1296
# conv.1.1.weight  :  parameters size torch.Size([144]) 	 parameters number 144
# conv.1.1.bias  :  parameters size torch.Size([144]) 	 parameters number 144
# conv.2.weight  :  parameters size torch.Size([24, 144, 1, 1]) 	 parameters number 3456
# conv.3.weight  :  parameters size torch.Size([24]) 	 parameters number 24
# conv.3.bias  :  parameters size torch.Size([24]) 	 parameters number 24
# ------------------------------------------------------------------
# 5-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#       (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 32, 28, 28])	 transport_num:6422528    transport_size:25.690MB
# conv.0.0.weight  :  parameters size torch.Size([144, 24, 1, 1]) 	 parameters number 3456
# conv.0.1.weight  :  parameters size torch.Size([144]) 	 parameters number 144
# conv.0.1.bias  :  parameters size torch.Size([144]) 	 parameters number 144
# conv.1.0.weight  :  parameters size torch.Size([144, 1, 3, 3]) 	 parameters number 1296
# conv.1.1.weight  :  parameters size torch.Size([144]) 	 parameters number 144
# conv.1.1.bias  :  parameters size torch.Size([144]) 	 parameters number 144
# conv.2.weight  :  parameters size torch.Size([32, 144, 1, 1]) 	 parameters number 4608
# conv.3.weight  :  parameters size torch.Size([32]) 	 parameters number 32
# conv.3.bias  :  parameters size torch.Size([32]) 	 parameters number 32
# ------------------------------------------------------------------
# 6-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 32, 28, 28])	 transport_num:6422528    transport_size:25.690MB
# conv.0.0.weight  :  parameters size torch.Size([192, 32, 1, 1]) 	 parameters number 6144
# conv.0.1.weight  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.0.1.bias  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.1.0.weight  :  parameters size torch.Size([192, 1, 3, 3]) 	 parameters number 1728
# conv.1.1.weight  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.1.1.bias  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.2.weight  :  parameters size torch.Size([32, 192, 1, 1]) 	 parameters number 6144
# conv.3.weight  :  parameters size torch.Size([32]) 	 parameters number 32
# conv.3.bias  :  parameters size torch.Size([32]) 	 parameters number 32
# ------------------------------------------------------------------
# 7-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 32, 28, 28])	 transport_num:6422528    transport_size:25.690MB
# conv.0.0.weight  :  parameters size torch.Size([192, 32, 1, 1]) 	 parameters number 6144
# conv.0.1.weight  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.0.1.bias  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.1.0.weight  :  parameters size torch.Size([192, 1, 3, 3]) 	 parameters number 1728
# conv.1.1.weight  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.1.1.bias  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.2.weight  :  parameters size torch.Size([32, 192, 1, 1]) 	 parameters number 6144
# conv.3.weight  :  parameters size torch.Size([32]) 	 parameters number 32
# conv.3.bias  :  parameters size torch.Size([32]) 	 parameters number 32
# ------------------------------------------------------------------
# 8-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 64, 14, 14])	 transport_num:3211264    transport_size:12.845MB
# conv.0.0.weight  :  parameters size torch.Size([192, 32, 1, 1]) 	 parameters number 6144
# conv.0.1.weight  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.0.1.bias  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.1.0.weight  :  parameters size torch.Size([192, 1, 3, 3]) 	 parameters number 1728
# conv.1.1.weight  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.1.1.bias  :  parameters size torch.Size([192]) 	 parameters number 192
# conv.2.weight  :  parameters size torch.Size([64, 192, 1, 1]) 	 parameters number 12288
# conv.3.weight  :  parameters size torch.Size([64]) 	 parameters number 64
# conv.3.bias  :  parameters size torch.Size([64]) 	 parameters number 64
# ------------------------------------------------------------------
# 9-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.002 s
# output shape: torch.Size([256, 64, 14, 14])	 transport_num:3211264    transport_size:12.845MB
# conv.0.0.weight  :  parameters size torch.Size([384, 64, 1, 1]) 	 parameters number 24576
# conv.0.1.weight  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.0.1.bias  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.1.0.weight  :  parameters size torch.Size([384, 1, 3, 3]) 	 parameters number 3456
# conv.1.1.weight  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.1.1.bias  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.2.weight  :  parameters size torch.Size([64, 384, 1, 1]) 	 parameters number 24576
# conv.3.weight  :  parameters size torch.Size([64]) 	 parameters number 64
# conv.3.bias  :  parameters size torch.Size([64]) 	 parameters number 64
# ------------------------------------------------------------------
# 10-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 64, 14, 14])	 transport_num:3211264    transport_size:12.845MB
# conv.0.0.weight  :  parameters size torch.Size([384, 64, 1, 1]) 	 parameters number 24576
# conv.0.1.weight  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.0.1.bias  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.1.0.weight  :  parameters size torch.Size([384, 1, 3, 3]) 	 parameters number 3456
# conv.1.1.weight  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.1.1.bias  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.2.weight  :  parameters size torch.Size([64, 384, 1, 1]) 	 parameters number 24576
# conv.3.weight  :  parameters size torch.Size([64]) 	 parameters number 64
# conv.3.bias  :  parameters size torch.Size([64]) 	 parameters number 64
# ------------------------------------------------------------------
# 11-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 64, 14, 14])	 transport_num:3211264    transport_size:12.845MB
# conv.0.0.weight  :  parameters size torch.Size([384, 64, 1, 1]) 	 parameters number 24576
# conv.0.1.weight  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.0.1.bias  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.1.0.weight  :  parameters size torch.Size([384, 1, 3, 3]) 	 parameters number 3456
# conv.1.1.weight  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.1.1.bias  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.2.weight  :  parameters size torch.Size([64, 384, 1, 1]) 	 parameters number 24576
# conv.3.weight  :  parameters size torch.Size([64]) 	 parameters number 64
# conv.3.bias  :  parameters size torch.Size([64]) 	 parameters number 64
# ------------------------------------------------------------------
# 12-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 96, 14, 14])	 transport_num:4816896    transport_size:19.268MB
# conv.0.0.weight  :  parameters size torch.Size([384, 64, 1, 1]) 	 parameters number 24576
# conv.0.1.weight  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.0.1.bias  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.1.0.weight  :  parameters size torch.Size([384, 1, 3, 3]) 	 parameters number 3456
# conv.1.1.weight  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.1.1.bias  :  parameters size torch.Size([384]) 	 parameters number 384
# conv.2.weight  :  parameters size torch.Size([96, 384, 1, 1]) 	 parameters number 36864
# conv.3.weight  :  parameters size torch.Size([96]) 	 parameters number 96
# conv.3.bias  :  parameters size torch.Size([96]) 	 parameters number 96
# ------------------------------------------------------------------
# 13-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 96, 14, 14])	 transport_num:4816896    transport_size:19.268MB
# conv.0.0.weight  :  parameters size torch.Size([576, 96, 1, 1]) 	 parameters number 55296
# conv.0.1.weight  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.0.1.bias  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.1.0.weight  :  parameters size torch.Size([576, 1, 3, 3]) 	 parameters number 5184
# conv.1.1.weight  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.1.1.bias  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.2.weight  :  parameters size torch.Size([96, 576, 1, 1]) 	 parameters number 55296
# conv.3.weight  :  parameters size torch.Size([96]) 	 parameters number 96
# conv.3.bias  :  parameters size torch.Size([96]) 	 parameters number 96
# ------------------------------------------------------------------
# 14-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 96, 14, 14])	 transport_num:4816896    transport_size:19.268MB
# conv.0.0.weight  :  parameters size torch.Size([576, 96, 1, 1]) 	 parameters number 55296
# conv.0.1.weight  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.0.1.bias  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.1.0.weight  :  parameters size torch.Size([576, 1, 3, 3]) 	 parameters number 5184
# conv.1.1.weight  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.1.1.bias  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.2.weight  :  parameters size torch.Size([96, 576, 1, 1]) 	 parameters number 55296
# conv.3.weight  :  parameters size torch.Size([96]) 	 parameters number 96
# conv.3.bias  :  parameters size torch.Size([96]) 	 parameters number 96
# ------------------------------------------------------------------
# 15-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.002 s
# output shape: torch.Size([256, 160, 7, 7])	 transport_num:2007040    transport_size:8.028MB
# conv.0.0.weight  :  parameters size torch.Size([576, 96, 1, 1]) 	 parameters number 55296
# conv.0.1.weight  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.0.1.bias  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.1.0.weight  :  parameters size torch.Size([576, 1, 3, 3]) 	 parameters number 5184
# conv.1.1.weight  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.1.1.bias  :  parameters size torch.Size([576]) 	 parameters number 576
# conv.2.weight  :  parameters size torch.Size([160, 576, 1, 1]) 	 parameters number 92160
# conv.3.weight  :  parameters size torch.Size([160]) 	 parameters number 160
# conv.3.bias  :  parameters size torch.Size([160]) 	 parameters number 160
# ------------------------------------------------------------------
# 16-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 160, 7, 7])	 transport_num:2007040    transport_size:8.028MB
# conv.0.0.weight  :  parameters size torch.Size([960, 160, 1, 1]) 	 parameters number 153600
# conv.0.1.weight  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.0.1.bias  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.1.0.weight  :  parameters size torch.Size([960, 1, 3, 3]) 	 parameters number 8640
# conv.1.1.weight  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.1.1.bias  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.2.weight  :  parameters size torch.Size([160, 960, 1, 1]) 	 parameters number 153600
# conv.3.weight  :  parameters size torch.Size([160]) 	 parameters number 160
# conv.3.bias  :  parameters size torch.Size([160]) 	 parameters number 160
# ------------------------------------------------------------------
# 17-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 160, 7, 7])	 transport_num:2007040    transport_size:8.028MB
# conv.0.0.weight  :  parameters size torch.Size([960, 160, 1, 1]) 	 parameters number 153600
# conv.0.1.weight  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.0.1.bias  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.1.0.weight  :  parameters size torch.Size([960, 1, 3, 3]) 	 parameters number 8640
# conv.1.1.weight  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.1.1.bias  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.2.weight  :  parameters size torch.Size([160, 960, 1, 1]) 	 parameters number 153600
# conv.3.weight  :  parameters size torch.Size([160]) 	 parameters number 160
# conv.3.bias  :  parameters size torch.Size([160]) 	 parameters number 160
# ------------------------------------------------------------------
# 18-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 320, 7, 7])	 transport_num:4014080    transport_size:16.056MB
# conv.0.0.weight  :  parameters size torch.Size([960, 160, 1, 1]) 	 parameters number 153600
# conv.0.1.weight  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.0.1.bias  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.1.0.weight  :  parameters size torch.Size([960, 1, 3, 3]) 	 parameters number 8640
# conv.1.1.weight  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.1.1.bias  :  parameters size torch.Size([960]) 	 parameters number 960
# conv.2.weight  :  parameters size torch.Size([320, 960, 1, 1]) 	 parameters number 307200
# conv.3.weight  :  parameters size torch.Size([320]) 	 parameters number 320
# conv.3.bias  :  parameters size torch.Size([320]) 	 parameters number 320
# ------------------------------------------------------------------
# 19-ConvNormActivation(
#   (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU6(inplace=True)
# )
# computation time: 0.001 s
# output shape: torch.Size([256, 1280, 7, 7])	 transport_num:16056320    transport_size:64.225MB
# 0.weight  :  parameters size torch.Size([1280, 320, 1, 1]) 	 parameters number 409600
# 1.weight  :  parameters size torch.Size([1280]) 	 parameters number 1280
# 1.bias  :  parameters size torch.Size([1280]) 	 parameters number 1280
# ------------------------------------------------------------------
# 20-AdaptiveAvgPool2d(output_size=(1, 1))
# computation time: 0.0 s
# output shape: torch.Size([256, 1280, 1, 1])	 transport_num:327680    transport_size:1.311MB
# ------------------------------------------------------------------
# 21-Flatten(start_dim=1, end_dim=-1)
# computation time: 0.0 s
# output shape: torch.Size([256, 1280])	 transport_num:327680    transport_size:1.311MB
# ------------------------------------------------------------------
# 22-Linear(in_features=1280, out_features=1000, bias=True)
# computation time: 0.334 s
# output shape: torch.Size([256, 1000])	 transport_num:256000    transport_size:1.024MB
# weight  :  parameters size torch.Size([1000, 1280]) 	 parameters number 1280000
# bias  :  parameters size torch.Size([1000]) 	 parameters number 1000

# %%
function.show_1model(mobileNet)
# Out:
# 1-ConvNormActivation(
#   (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU6(inplace=True)
# )
# 2-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 3-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 4-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#       (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 5-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#       (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 6-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 7-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 8-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#       (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 9-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 10-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 11-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 12-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 13-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 14-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 15-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#       (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 16-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 17-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 18-InvertedResidual(
#   (conv): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): ConvNormActivation(
#       (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#       (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# 19-ConvNormActivation(
#   (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU6(inplace=True)
# )
# 20-AdaptiveAvgPool2d(output_size=(1, 1))
# 21-Flatten(start_dim=1, end_dim=-1)
# 22-Linear(in_features=1280, out_features=1000, bias=True)
# 23-AdaptiveAvgPool2d(output_size=(1, 1))
# 24-Flatten(start_dim=1, end_dim=-1)
# 25-Linear(in_features=1280, out_features=1000, bias=True)

# %%
import torch
import function
import a3_GoogLeNet

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# D:\Anaconda\envs\pytorch\lib\site-packages\torchvision\models\googlenet.py:46: FutureWarning: The default weight initialization of GoogleNet will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# cuda

# %%
x = torch.rand(size=(32,3,224,224))
x = x.to(device)
print(f"x device : {x.device}")

GoogLeNet = a3_GoogLeNet.GoogLeNet()
GoogLeNet = GoogLeNet.to(device)
# Out:
# x device : cuda:0

# %%
print(len(GoogLeNet))
# Out:
# 20

# %%
temp_x = x
with torch.no_grad():
    temp_x = function.show_features(GoogLeNet,temp_x)
# Out:
# ------------------------------------------------------------------
# 1-BasicConv2d(
#   (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# computation time: 0.773 s
# output shape: torch.Size([32, 64, 112, 112])	 transport_num:25690112    transport_size:102.760MB
# conv.weight  :  parameters size torch.Size([64, 3, 7, 7]) 	 parameters number 9408
# bn.weight  :  parameters size torch.Size([64]) 	 parameters number 64
# bn.bias  :  parameters size torch.Size([64]) 	 parameters number 64
# ------------------------------------------------------------------
# 2-MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# computation time: 0.0 s
# output shape: torch.Size([32, 64, 55, 55])	 transport_num:6195200    transport_size:24.781MB
# ------------------------------------------------------------------
# 3-BasicConv2d(
# ...

# %%
function.show_1model(GoogLeNet)
# Out:
# 1-BasicConv2d(
#   (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# 2-MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# 3-BasicConv2d(
#   (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# 4-BasicConv2d(
#   (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# 5-MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# 6-Inception(
#   (branch1): BasicConv2d(
#     (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch2): Sequential(
# ...
